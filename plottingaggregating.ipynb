# %%
import pandas
from datetime import datetime
from pytz import utc 

#to do plotting we need to add the library
import matplotlib.pyplot as plt

data = pandas.read_csv("reviews.csv", parse_dates=['Timestamp'])
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %%
# we use groupby to add identical values together 
#we use data['Day'] to create idential data in a column
data['Day'] = data['Timestamp'].dt.date
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment         Day
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021-04-02
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021-04-02

# %%
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date
#average rating for that course for that day 
day_average = data.groupby(['Day']).mean()
day_average.head()
# Out:
#               Rating
# Day
# 2018-01-01  4.532609
# 2018-01-02  4.122807
# 2018-01-03  4.360465
# 2018-01-04  4.531250
# 2018-01-05  4.423077

# %%
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date
#average rating for that course for that day 
day_average = data.groupby(['Day']).mean()

#.mean only calculates numbers like ratings and others 
day_average.index
# Out:
# Index([2018-01-01, 2018-01-02, 2018-01-03, 2018-01-04, 2018-01-05, 2018-01-06,
#        2018-01-07, 2018-01-08, 2018-01-09, 2018-01-10,
#        ...
#        2021-03-24, 2021-03-25, 2021-03-26, 2021-03-27, 2021-03-28, 2021-03-29,
#        2021-03-30, 2021-03-31, 2021-04-01, 2021-04-02],
#       dtype='object', name='Day', length=1188)

# %%
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date

#average rating for that course for that day 
day_average = data.groupby(['Day']).count()

#46 ratings made for the day

#.mean only calculates numbers like ratings and others 
day_average.head()
# Out:
#             Course Name  Timestamp  Rating  Comment
# Day
# 2018-01-01           46         46      46        7
# 2018-01-02           57         57      57       16
# 2018-01-03           43         43      43        8
# 2018-01-04           48         48      48       11
# 2018-01-05           52         52      52       15

# %%
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date
#average rating for that course for that day 
day_average = data.groupby(['Day']).mean()
# CONVERTING INDEX INTO A LIST
list(day_average.index)
# Out:
# [datetime.date(2018, 1, 1),
#  datetime.date(2018, 1, 2),
#  datetime.date(2018, 1, 3),
#  datetime.date(2018, 1, 4),
#  datetime.date(2018, 1, 5),
#  datetime.date(2018, 1, 6),
#  datetime.date(2018, 1, 7),
#  datetime.date(2018, 1, 8),
#  datetime.date(2018, 1, 9),
#  datetime.date(2018, 1, 10),
#  datetime.date(2018, 1, 11),
#  datetime.date(2018, 1, 12),
#  datetime.date(2018, 1, 13),
#  datetime.date(2018, 1, 14),
#  datetime.date(2018, 1, 15),
#  datetime.date(2018, 1, 16),
#  datetime.date(2018, 1, 17),
#  datetime.date(2018, 1, 18),
#  datetime.date(2018, 1, 19),
#  datetime.date(2018, 1, 20),
#  datetime.date(2018, 1, 21),
#  datetime.date(2018, 1, 22),
#  datetime.date(2018, 1, 23),
#  datetime.date(2018, 1, 24),
#  datetime.date(2018, 1, 25),
#  datetime.date(2018, 1, 26),
#  datetime.date(2018, 1, 27),
#  datetime.date(2018, 1, 28),
#  datetime.date(2018, 1, 29),
#  datetime.date(2018, 1, 30),
#  datetime.date(2018, 1, 31),
#  datetime.date(2018, 2, 1),
# ...

# %% [markdown]
# ## PLOTTING GRAPH

# %% [markdown]
# ### DAILY AVERAGE PLOTTING

# %%
#PLOTTING GRAPH FOR DAILY AVERGAE
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date


#average rating for that course for that day 
day_average = data.groupby(['Day']).mean()

#import plotting to show x and y axis
plt.plot(day_average.index, day_average['Rating'])

# %%
# aggregate the mean
data['Day'] = data['Timestamp'].dt.date
#average rating for that course for that day 
day_average = data.groupby(['Day']).mean()

plt.figure(figsize=(25, 3))
#import plotting to show x and y axis
plt.plot(day_average.index, day_average['Rating'])

# %% [markdown]
# ###  PLOTTING WEEKLY AVERAGE

# %%
data['Week'] = data['Timestamp'].dt.week
# Out:
# /var/folders/l4/w9kvm06d62148qflnvxx66b80000gn/T/ipykernel_11161/1988753933.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['Week'] = data['Timestamp'].dt.week
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
# ...

# %%
#maximum weeks
data['Week'] = data['Timestamp'].dt.week
data['Week'].max()
# Out:
# /var/folders/l4/w9kvm06d62148qflnvxx66b80000gn/T/ipykernel_11161/2478987353.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['Week'] = data['Timestamp'].dt.week
# 53

# %%
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
data['Week']
# Out:
# 0        2021-13-04
# 1        2021-13-04
# 2        2021-13-04
# 3        2021-13-04
# 4        2021-13-04
#             ...
# 44995    2018-00-01
# 44996    2018-00-01
# 44997    2018-00-01
# 44998    2018-00-01
# 44999    2018-00-01
# Name: Week, Length: 45000, dtype: object

# %%
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
week_average = data.groupby(['Week']).mean()
week_average
# Out:
#               Rating
# Week
# 2018-00-01  4.434564
# 2018-01-01  4.424933
# 2018-02-01  4.417702
# 2018-03-01  4.401024
# 2018-04-01  4.500000
# ...              ...
# 2021-10-03  4.627315
# 2021-11-03  4.629121
# 2021-12-03  4.607843
# 2021-13-03  4.396694
# 2021-13-04  4.544118
#
# [203 rows x 1 columns]

# %%
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
week_average = data.groupby(['Week']).mean()

#to fetch the week column
week_average.index
# Out:
# Index(['2018-00-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#        '2018-04-02', '2018-05-02', '2018-06-02', '2018-07-02', '2018-08-02',
#        ...
#        '2021-06-02', '2021-07-02', '2021-08-02', '2021-09-02', '2021-09-03',
#        '2021-10-03', '2021-11-03', '2021-12-03', '2021-13-03', '2021-13-04'],
#       dtype='object', name='Week', length=203)

# %%
#PLOTTING
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
week_average = data.groupby(['Week']).mean()

plt.plot(week_average.index, week_average['Rating'])

# %%
#PLOTTING
data['Week'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
week_average = data.groupby(['Week']).mean()

#MODIFY THE FIGURES
plt.figure(figsize=(25,3))
plt.plot(week_average.index, week_average['Rating'])

# %% [markdown]
# ### PLOTTING MONTHLY AVERAGE

# %%
#PLOTTING
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average = data.groupby(['Month']).mean()

plt.plot(month_average.index, month_average['Rating'])

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average = data.groupby(['Month']).mean()

plt.figure(figsize=(25, 3))
plt.plot(month_average.index, month_average['Rating'])

# %% [markdown]
# ## Average rating by month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average_crs = data.groupby(['Month', 'Course Name']).mean()
month_average_crs
# Out:
#                                                                  Rating
# Month      Course Name
# 2018-00-01 100 Python Exercises I: Evaluate and Improve Yo...  4.583333
#            Data Processing with Python                         4.875000
#            Interactive Data Visualization with Python and ...  3.928571
#            Learn GIS in One Hour                               5.000000
#            Python for Beginners with Examples                  4.265957
# ...                                                                 ...
# 2021-13-03 The Python Mega Course: Build 10 Real World App...  4.468750
# 2021-13-04 100 Python Exercises I: Evaluate and Improve Yo...  4.500000
#            Interactive Data Visualization with Python and ...  5.000000
#            The Complete Python Course: Build 10 Profession...  4.250000
#            The Python Mega Course: Build 10 Real World App...  4.576923
#
# [1247 rows x 1 columns]

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average_crs = data.groupby(['Month', 'Course Name']).mean()
#first 20 records
month_average_crs[:20]
# Out:
#                                                                  Rating
# Month      Course Name
# 2018-00-01 100 Python Exercises I: Evaluate and Improve Yo...  4.583333
#            Data Processing with Python                         4.875000
#            Interactive Data Visualization with Python and ...  3.928571
#            Learn GIS in One Hour                               5.000000
#            Python for Beginners with Examples                  4.265957
#            The Python Mega Course: Build 10 Real World App...  4.464602
# 2018-01-01 100 Python Exercises I: Evaluate and Improve Yo...  4.107143
#            Data Processing with Python                         4.428571
#            Interactive Data Visualization with Python and ...  3.900000
#            Learn GIS in One Hour                               4.333333
#            Python for Beginners with Examples                  4.254545
#            The Python Mega Course: Build 10 Real World App...  4.482699
# ...

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average_crs = data.groupby(['Month', 'Course Name']).mean().unstack()
#first 20 records
month_average_crs[:20]
# Out:
#                                                               Rating  \
# Course Name 100 Python Exercises I: Evaluate and Improve Your Skills
# Month
# 2018-00-01                                            4.583333
# 2018-01-01                                            4.107143
# 2018-02-01                                            4.166667
# 2018-03-01                                            4.083333
# 2018-04-01                                            4.863636
# 2018-04-02                                            3.900000
# 2018-05-02                                            4.500000
# 2018-06-02                                            4.312500
# 2018-07-02                                            4.500000
# 2018-08-02                                            3.750000
# 2018-08-03                                            4.571429
# 2018-09-03                                            4.555556
# 2018-10-03                                            4.500000
# ...

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%U-%m')
month_average_crs = data.groupby(['Month', 'Course Name']).mean().unstack()

month_average_crs.plot(figsize=(25, 8))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
month_average_crs = data.groupby(['Month', 'Course Name']).count().unstack()

month_average_crs.plot(figsize=(25, 8))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ### DAY OF THE WEEK PEOPLE ARE HAPPIEST?

# %%
data['Weekday'] = data['Timestamp'].dt.strftime('%A')
data
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day        Week  \
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021-13-04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021-13-04
# ...

# %%
#GETTING THE AVERAGE OF THE WEEKDAY
data['Weekday'] = data['Timestamp'].dt.strftime('%A')

weekday_average = data.groupby(['Weekday']).mean()
weekday_average
# Out:
#              Rating
# Weekday
# Friday     4.455207
# Monday     4.449335
# Saturday   4.440274
# Sunday     4.439097
# Thursday   4.437880
# Tuesday    4.446240
# Wednesday  4.427452

# %%
#GETTING THE AVERAGE OF THE WEEKDAY
data['Weekday'] = data['Timestamp'].dt.strftime('%A')

weekday_average = data.groupby(['Weekday']).mean()

plt.plot(weekday_average.index, weekday_average['Rating'])

# %%
#GETTING THE AVERAGE OF THE WEEKDAY using string from time
data['Weekday'] = data['Timestamp'].dt.strftime('%A')
data['Daynumber'] = data['Timestamp'].dt.strftime('%w')

weekday_average = data.groupby(['Weekday', 'Daynumber']).mean()
weekday_average = weekday_average.sort_values('Daynumber')

weekday_average.index.get_level_values(0)
#plt.plot(weekday_average.index, weekday_average['Rating'])
# Out:
# Index(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'],
#       dtype='object', name='Weekday')

# %%
data['Weekday'] = data['Timestamp'].dt.strftime('%A')
data['Daynumber'] = data['Timestamp'].dt.strftime('%w')

weekday_average = data.groupby(['Weekday', 'Daynumber']).mean()
weekday_average = weekday_average.sort_values('Daynumber')

#array we plot on x -axis
plt.plot(weekday_average.index.get_level_values(0), weekday_average['Rating'])

# %%
data['Weekday'] = data['Timestamp'].dt.strftime('%A')
data['Daynumber'] = data['Timestamp'].dt.strftime('%w')

weekday_average = data.groupby(['Weekday', 'Daynumber']).mean()
weekday_average = weekday_average.sort_values('Daynumber')

#better map display using figures with better ratios [15,3]
plt.figure(figsize=[15,3])

#array we plot on x -axis
plt.plot(weekday_average.index.get_level_values(0), weekday_average['Rating'])

# %%
# using additional types of plots
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
# ...

# %% [markdown]
# ## Numbers  of colums per course

# %%
#get the number of each course ratings 
share = data.groupby(['Course Name']).count()
share
# Out:
#                                                     Timestamp  Rating  \
# Course Name
# 100 Python Exercises I: Evaluate and Improve Yo...       1593    1593
# 100 Python Exercises II: Evaluate and Improve Y...        280     280
# Data Processing with Python                               868     868
# Interactive Data Visualization with Python and ...        767     767
# Learn GIS in One Hour                                     499     499
# Python for Beginners with Examples                       4821    4821
# The Complete Python Course: Build 10 Profession...        470     470
# The Python Mega Course: Build 10 Real World App...      35702   35702
#
#                                                     Comment    Day   Week  \
# Course Name
# 100 Python Exercises I: Evaluate and Improve Yo...      231   1593   1593
# 100 Python Exercises II: Evaluate and Improve Y...       81    280    280
# Data Processing with Python                             117    868    868
# ...

# %%
##Numbers of ratings per course 
#get the number of each course ratings 
share = data.groupby(['Course Name'])['Rating'].count()
share
# Out:
# Course Name
# 100 Python Exercises I: Evaluate and Improve Your Skills       1593
# 100 Python Exercises II: Evaluate and Improve Your Skills       280
# Data Processing with Python                                     868
# Interactive Data Visualization with Python and Bokeh            767
# Learn GIS in One Hour                                           499
# Python for Beginners with Examples                             4821
# The Complete Python Course: Build 10 Professional OOP Apps      470
# The Python Mega Course: Build 10 Real World Applications      35702
# Name: Rating, dtype: int64

# %%
# PIE takes in an X argument which is share 
#making a pie chart with labels 
plt.pie(share, labels=share.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fda39ea92b0>,
# ...
#  [Text(1.0932045021416132, 0.12208159770132226, '100 Python Exercises I: Evaluate and Improve Your Skills'),
#   Text(1.0679539537181753, 0.26357987923534204, '100 Python Exercises II: Evaluate and Improve Your Skills'),
#   Text(1.0434237552357248, 0.34823392570193146, 'Data Processing with Python'),
#   Text(0.9969710234481678, 0.46481047579063145, 'Interactive Data Visualization with Python and Bokeh'),
#   Text(0.9520514707070057, 0.5509972750609823, 'Learn GIS in One Hour'),
#   Text(0.6871674297354248, 0.858953388438983, 'Python for Beginners with Examples'),
#   Text(0.3307031314068022, 1.0491117380325774, 'The Complete Python Course: Build 10 Professional OOP Apps'),
#   Text(-0.8762757995015485, -0.6649366309716455, 'The Python Mega Course: Build 10 Real World Applications')])
